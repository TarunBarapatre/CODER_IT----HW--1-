# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
os.chdir('C:\\Users\\DELL\\Desktop\\Data Framing')

# %%
dataset = pd.read_csv('BigMartSalesData.csv')

# %%
dataset
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
dataset.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1452
# Quantity            0
# UnitPrice           0
# Amount              0
# InvoiceDate         0
# Day                 0
# Month               0
# Year                0
# CustomerID     135045
# Country             0
# dtype: int64

# %%
dataset.isna().mean().round(4) * 100
# Out:
# InvoiceNo       0.00
# StockCode       0.00
# Description     0.27
# Quantity        0.00
# UnitPrice       0.00
# Amount          0.00
# InvoiceDate     0.00
# Day             0.00
# Month           0.00
# Year            0.00
# CustomerID     24.92
# Country         0.00
# dtype: float64

# %%
import seaborn as sns
sns.boxplot(y='Quantity',data=dataset)

# %%
outer_lier_1=dataset.iloc[:,3:4]

# %%
Q1 = outer_lier_1.quantile(0.25)
Q3 = outer_lier_1.quantile(0.75)
IQR = Q3-Q1

# %%
outer_lier_1 = outer_lier_1[~((outer_lier_1<(Q1-1.5*IQR))
                       | (outer_lier_1>(Q3+1.5*IQR))).any(axis=1)]

# %%
outer_lier_1
# Out:
#         Quantity
# 0              6
# 1              6
# 2              8
# 3              6
# 4              6
# 5              2
# 6              6
# 7              6
# 8              6
# 10             6
# 11             6
# 12             8
# 13             6
# 14             6
# 15             3
# 16             2
# 17             3
# 18             3
# 19             4
# 20             4
# 21             6
# 22             3
# 23             3
# 24             3
# 25             3
# 28            12
# 29            12
# 33            18
# 38            20
# 41            12
# ...          ...
# 541839        12
# 541840        16
# 541842         4
# 541843         3
# 541844         8
# 541845         4
# 541846        10
# 541849        12
# 541850        12
# 541851        12
# 541852         4
# 541853        12
# 541854        12
# 541855         8
# 541858        10
# 541859        12
# 541860        12
# 541861        12
# 541862         4
# 541863         4
# ...

# %%
sns.boxplot(y='Quantity',data=outer_lier_1)

# %%
sns.boxplot(y='UnitPrice',data=dataset)

# %%
outer_lier_2=dataset.iloc[:,4:5]

# %%
Q1 = outer_lier_2.quantile(0.25)
Q3 = outer_lier_2.quantile(0.75)
IQR = Q3-Q1

# %%
outer_lier_2 = outer_lier_2[~((outer_lier_2<(Q1-1.5*IQR))
                       | (outer_lier_2>(Q3+1.5*IQR))).any(axis=1)]

# %%
outer_lier_2
# Out:
#         UnitPrice
# 0            2.55
# 1            3.39
# 2            2.75
# 3            3.39
# 4            3.39
# 5            7.65
# 6            4.25
# 7            1.85
# 8            1.85
# 9            1.69
# 10           2.10
# 11           2.10
# 12           3.75
# 13           1.65
# 14           4.25
# 15           4.95
# 17           5.95
# 18           5.95
# 19           7.95
# 20           7.95
# 21           4.25
# 22           4.95
# 23           4.95
# 24           4.95
# 25           5.95
# 26           3.75
# 27           3.75
# 28           3.75
# 29           0.85
# 30           0.65
# ...           ...
# 541843       5.95
# 541844       3.75
# 541845       3.75
# 541846       0.85
# 541847       0.42
# 541848       0.42
# 541849       1.25
# 541850       0.85
# 541851       0.39
# 541852       3.75
# 541853       0.95
# 541854       1.95
# 541855       2.95
# 541856       1.25
# 541858       7.08
# 541859       1.95
# 541860       1.65
# 541861       1.65
# ...

# %%
sns.boxplot(y='UnitPrice',data=outer_lier_2)

# %%
sns.boxplot(y='Amount',data=dataset)

# %%
outer_lier_3=dataset.iloc[:,5:6]

# %%
outer_lier_3
# Out:
#         Amount
# 0        15.30
# 1        20.34
# 2        22.00
# 3        20.34
# 4        20.34
# 5        15.30
# 6        25.50
# 7        11.10
# 8        11.10
# 9        54.08
# 10       12.60
# 11       12.60
# 12       30.00
# 13        9.90
# 14       25.50
# 15       14.85
# 16       19.90
# 17       17.85
# 18       17.85
# 19       31.80
# 20       31.80
# 21       25.50
# 22       14.85
# 23       14.85
# 24       14.85
# 25       17.85
# 26       90.00
# 27       90.00
# 28       45.00
# 29       10.20
# ...        ...
# 541844   30.00
# 541845   15.00
# 541846    8.50
# 541847   10.08
# 541848   10.50
# 541849   15.00
# 541850   10.20
# 541851    4.68
# 541852   15.00
# 541853   11.40
# 541854   23.40
# 541855   23.60
# 541856   30.00
# 541857  214.80
# 541858   70.80
# 541859   23.40
# 541860   19.80
# 541861   19.80
# 541862   15.00
# 541863   15.00
# 541864   15.00
# 541865   15.00
# 541866   15.60
# 541867   23.40
# 541868   16.60
# 541869   10.20
# ...

# %%
Q1 = outer_lier_3.quantile(0.25)
Q3 = outer_lier_3.quantile(0.75)
IQR = Q3-Q1

# %%
outer_lier_3 = outer_lier_3[~((outer_lier_3<(Q1-1.5*IQR))
                       | (outer_lier_3>(Q3+1.5*IQR))).any(axis=1)]

# %%
type(outer_lier_3)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.boxplot(y='Amount',data=outer_lier_3)

# %%
sns.regplot(x='Amount', y='Quantity', data=dataset, fit_reg=False)

# %%
sns.barplot(x='Country', y='Amount', data=dataset)

# %%
sns.stripplot(y='Year',x='Quantity',data=dataset)

# %%
dataset.plot()
